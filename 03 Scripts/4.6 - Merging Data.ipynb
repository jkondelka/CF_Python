# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Define a dictionary containing January 2020 data 

data1 = {'customer_id':['6732', '767', '890', '635'], 
        'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'], 
        'purchased_meat':[0, 13, 3, 4], 
        'purchased_alcohol':[1, 2, 10, 0],
        'purchased_snacks': [10, 5, 1, 7]}

# %%
# Define a dictionary containing February 2020 data 

data2 = {'customer_id':['6732', '767', '890', '635'], 
        'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'], 
        'purchased_meat':[0, 10, 5, 3], 
        'purchased_alcohol':[2, 4, 14, 0],
        'purchased_snacks': [15, 3, 2, 6]}

# %%
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df_1 = pd.DataFrame(data2,index=[0, 1, 2, 3])

# %%
data1
# Out:
# {'customer_id': ['6732', '767', '890', '635'],
#  'month': ['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
#  'purchased_meat': [0, 13, 3, 4],
#  'purchased_alcohol': [1, 2, 10, 0],
#  'purchased_snacks': [10, 5, 1, 7]}

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7

# %%
frantisek = [df, df_1]

# %%
df_concat = pd.concat(frantisek)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
df_concat = pd.concat(frantisek, axis = 1)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# __Appending__

# %%
df_appended = df.append(df_1)
# Out:
# /var/folders/wg/x5vnthvs2yz9v9gxlgg29_mm0000gn/T/ipykernel_74377/1899069771.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_appended = df.append(df_1)

# %%
df_appended
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# Create data with different columns from df
data3 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'days_purchased_on':[0, 13, 3, 4]}

# Convert to dataframe
df_2 = pd.DataFrame(data3,index=[0, 1, 2, 3])

# %%
df_append_test = df.append(df_2)
# Out:
# /var/folders/wg/x5vnthvs2yz9v9gxlgg29_mm0000gn/T/ipykernel_74377/2564146318.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_test = df.append(df_2)

# %%
df_append_test
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20             0.0                1.0              10.0
# 1         767  Jan-20            13.0                2.0               5.0
# 2         890  Jan-20             3.0               10.0               1.0
# 3         635  Jan-20             4.0                0.0               7.0
# 0        6732  Jan-20             NaN                NaN               NaN
# 1         767  Jan-20             NaN                NaN               NaN
# 2         890  Jan-20             NaN                NaN               NaN
# 3         635  Jan-20             NaN                NaN               NaN
#
#    days_purchased_on
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 0                0.0
# 1               13.0
# 2                3.0
# 3                4.0

# %% [markdown]
# __MERGE__
#
# it is just like joins with argument __ON__ to determine which column to join on.
# Joins are INNER,LEFT,RIGHT,FULL JOIN

# %%
df_merged = df.merge(df_2, on = 'customer_id')

# %%
df_merged
# Out:
#   customer_id month_x  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   month_y  days_purchased_on
# 0  Jan-20                  0
# 1  Jan-20                 13
# 2  Jan-20                  3
# 3  Jan-20                  4

# %%
# using 2 columns as arguments
df_merged = df.merge(df_2, on = ['customer_id', 'month'])

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on
# 0                  0
# 1                 13
# 2                  3
# 3                  4

# %%
# indicate if merge is FULL, RIGHT or LEFT

df_merged = df.merge(df_2, on = ['customer_id', 'month'], indicator = True)

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 13   both
# 2                  3   both
# 3                  4   both

# %%
df_merged['_merge'].value_counts()
# Out:
# both          4
# left_only     0
# right_only    0
# Name: _merge, dtype: int64

# %%
path = r'/Users/jakubkondelka/Documents/CF_Instacart Basket Analysis'

# %%
# import df_ords_prior
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
df_ords_prior.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# import df_ords
df_ords2 = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
df_ords2.head()
# Out:
#    Unnamed: 0  order_id  user_id evaluations  order_number  \
# 0           0   2539329        1       prior             1
# 1           1   2398795        1       prior             2
# 2           2    473747        1       prior             3
# 3           3   2254736        1       prior             4
# 4           4    431534        1       prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
df_ords = df_ords2.drop(columns = ['Unnamed: 0'])

# %%
df_ords
# Out:
#          order_id  user_id evaluations  order_number  orders_day_of_week  \
# 0         2539329        1       prior             1                   2
# 1         2398795        1       prior             2                   3
# 2          473747        1       prior             3                   3
# 3         2254736        1       prior             4                   4
# 4          431534        1       prior             5                   4
# ...           ...      ...         ...           ...                 ...
# 3421078   2266710   206209       prior            10                   5
# 3421079   1854736   206209       prior            11                   4
# 3421080    626363   206209       prior            12                   1
# 3421081   2977660   206209       prior            13                   1
# 3421082    272231   206209       train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %% [markdown]
# __Merge data frames on__ order_id

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id evaluations  order_number  orders_day_of_week  \
# 0   2539329        1       prior             1                   2
# 1   2539329        1       prior             1                   2
# 2   2539329        1       prior             1                   2
# 3   2539329        1       prior             1                   2
# 4   2539329        1       prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export data to pkl

df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
